# %%
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.dataset import BloodCellDataset

dataset = BloodCellDataset(
    './data',
    image_size=(1024, 1024),
    num_samples=100,
    augment=True,
)

# %%
print(len(dataset))
# Out:
# 100

# %%
res = dataset[6]

plt.imshow(res)
plt.show()

# %%
res = dataset[7]

plt.imshow(res)
plt.show()

# %%
res = dataset[8]

plt.imshow(res)
plt.show()
